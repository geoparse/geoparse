# %% [markdown]
# <h1 align="center"><img align="center" src="data/geoparse_logo.png" alt="GeoParse Logo" width="200"/></h1>
# <h1 align="center">GeoParse</h1>
# <h3 align="center">It's all about points <img src="data/point.png" width="10"/> lines <img src="data/line.png" width="40"/> and polygons <img src="data/polygon.png" width="30"/></h3>
#
#
#
# #### [Website](http://geoparse.io)
# ***
#
# # Geospatial Index
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/geoparse/geoparse/main?labpath=tutorials%2F00_visualization.ipynb)
#
# This notebook demonstrates how to convert coordinates into spatial indexes (H3, S2, and Geohash) and back into coordinates.
# ***

# %%
# Add parent directory to sys.path
import os
import sys

sys.path.append(os.path.abspath(".."))

# %%
import warnings

import pandas as pd

from geoparse.geoparse import SpatialIndex
from geoparse.karta import plp

warnings.filterwarnings("ignore")

# %%
#reload all changed modules every time before executing a new line
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Read from CSV file

# %%
df = pd.read_csv("data/great_britain_road_casualties-2023.csv")
df.head()
# Out:
#          date   time   latitude  longitude  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551  -0.097759                   1
# 1  07/01/2023  10:05  51.593701   0.022379                   1
# 2  14/01/2023  16:15  51.466689  -0.011289                   1
# 3  15/01/2023  19:51  51.671577  -0.037543                   1
# 4  16/01/2023  19:22  51.447944   0.117279                   2
#
#    number_of_casualties  speed_limit
# 0                     1           30
# 1                     1           30
# 2                     1           20
# 3                     1           30
# 4                     1           30

# %%
len(df)
# Out:
# 1522

# %%
plp(df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6fccf8350487d4b13049fb036babb40b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6fccf8350487d4b13049fb036babb40b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6fccf8350487d4b13049fb036babb40b = L.map(
#                 &quot;map_6fccf8350487d4b13049fb036babb40b&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da66af57f5f4a695eb1914f551505cb0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 21,
#   &quot;maxNativeZoom&quot;: 21,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_da66af57f5f4a695eb1914f551505cb0.addTo(map_6fccf8350487d4b13049fb036babb40b);
#
#
#             var tile_layer_e2556162aa649285b354ba434b5e40b9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 21,
#   &quot;maxNativeZoom&quot;: 21,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2556162aa649285b354ba434b5e40b9.addTo(map_6fccf8350487d4b13049fb036babb40b);
#
#
#             var tile_layer_de7a3e21ce566ce5b62735102a25575c = L.tileLayer(
#                 &quot;https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u00a9 \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u00a9 \u003ca href=\&quot;https://opentopomap.org/\&quot;\u003eOpenTopoMap\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de7a3e21ce566ce5b62735102a25575c.addTo(map_6fccf8350487d4b13049fb036babb40b);
#
#
#             var tile_layer_40b403f71aff2d8824db5fa0d1433b36 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u00a9 \u003ca href=\&quot;https://www.esri.com/en-us/legal/overview\&quot;\u003eEsri\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_40b403f71aff2d8824db5fa0d1433b36.addTo(map_6fccf8350487d4b13049fb036babb40b);
#
#
#             var tile_layer_dd76b42dacd7c1234b26f0c33370aed9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd76b42dacd7c1234b26f0c33370aed9.addTo(map_6fccf8350487d4b13049fb036babb40b);
#
#
#             map_6fccf8350487d4b13049fb036babb40b.fitBounds(
#                 [[50.108901, -6.606332], [60.252418, 1.725243]],
#                 {}
#             );
#
#
#             var feature_group_274eb3427544ff5d5b0f18263101b881 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_122001046979bc7146df98d67cda4253 = L.circleMarker(
#                 [51.356551, -0.097759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;:

# %%
# %%time
df["h3"] = SpatialIndex.ppointcell(df.latitude, df.longitude, cell_type="h3", res=15)
df.head()
# Out:
# CPU times: user 53.1 ms, sys: 116 ms, total: 170 ms
# Wall time: 1.99 s
#          date   time   latitude  longitude  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551  -0.097759                   1
# 1  07/01/2023  10:05  51.593701   0.022379                   1
# 2  14/01/2023  16:15  51.466689  -0.011289                   1
# 3  15/01/2023  19:51  51.671577  -0.037543                   1
# 4  16/01/2023  19:22  51.447944   0.117279                   2
#
#    number_of_casualties  speed_limit               h3
# 0                     1           30  8f194ac22370811
# 1                     1           30  8f194e68042a851
# 2                     1           20  8f194ad058a4c04
# 3                     1           30  8f195db6b2d6cca
# 4                     1           30  8f194e6deb25ac9

# %%
# %%time
df[["lat", "lon"]] = SpatialIndex.pcellpoint(df.h3, cell_type="h3")
df.head()
# Out:
# CPU times: user 42.3 ms, sys: 101 ms, total: 144 ms
# Wall time: 1.62 s
#          date   time   latitude  longitude  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551  -0.097759                   1
# 1  07/01/2023  10:05  51.593701   0.022379                   1
# 2  14/01/2023  16:15  51.466689  -0.011289                   1
# 3  15/01/2023  19:51  51.671577  -0.037543                   1
# 4  16/01/2023  19:22  51.447944   0.117279                   2
#
#    number_of_casualties  speed_limit               h3        lat       lon
# 0                     1           30  8f194ac22370811  51.356552 -0.097765
# 1                     1           30  8f194e68042a851  51.593698  0.022381
# 2                     1           20  8f194ad058a4c04  51.466687 -0.011286
# 3                     1           30  8f195db6b2d6cca  51.671579 -0.037540
# 4                     1           30  8f194e6deb25ac9  51.447941  0.117280

# %%
max(abs(df.latitude - df.lat)), max(abs(df.longitude - df.lon))
# Out:
# (4.954881163143909e-06, 8.070243062263671e-06)

# %%
# %%time
df["s2"] = SpatialIndex.ppointcell(df.latitude, df.longitude, cell_type="s2", res=30)
df.head()
# Out:
# CPU times: user 44.6 ms, sys: 98.2 ms, total: 143 ms
# Wall time: 1.51 s
#          date   time   latitude  longitude  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551  -0.097759                   1
# 1  07/01/2023  10:05  51.593701   0.022379                   1
# 2  14/01/2023  16:15  51.466689  -0.011289                   1
# 3  15/01/2023  19:51  51.671577  -0.037543                   1
# 4  16/01/2023  19:22  51.447944   0.117279                   2
#
#    number_of_casualties  speed_limit               h3        lat       lon  \
# 0                     1           30  8f194ac22370811  51.356552 -0.097765
# 1                     1           30  8f194e68042a851  51.593698  0.022381
# 2                     1           20  8f194ad058a4c04  51.466687 -0.011286
# 3                     1           30  8f195db6b2d6cca  51.671579 -0.037540
# 4                     1           30  8f194e6deb25ac9  51.447941  0.117280
#
#                  s2
# 0  487607526cb67e75
# 1  47d8a749f4303a43
# 2  4876027b49457ecb
# 3  48761f9ac2a128c7
# 4  47d8ae95f533fc95

# %%
# %%time
df[["lat", "lon"]] = SpatialIndex.pcellpoint(df.s2, cell_type="s2")
df.head()
# Out:
# CPU times: user 41.7 ms, sys: 103 ms, total: 145 ms
# Wall time: 1.52 s
#          date   time   latitude  longitude  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551  -0.097759                   1
# 1  07/01/2023  10:05  51.593701   0.022379                   1
# 2  14/01/2023  16:15  51.466689  -0.011289                   1
# 3  15/01/2023  19:51  51.671577  -0.037543                   1
# 4  16/01/2023  19:22  51.447944   0.117279                   2
#
#    number_of_casualties  speed_limit               h3        lat       lon  \
# 0                     1           30  8f194ac22370811  51.356551 -0.097759
# 1                     1           30  8f194e68042a851  51.593701  0.022379
# 2                     1           20  8f194ad058a4c04  51.466689 -0.011289
# 3                     1           30  8f195db6b2d6cca  51.671577 -0.037543
# 4                     1           30  8f194e6deb25ac9  51.447944  0.117279
#
#                  s2
# 0  487607526cb67e75
# 1  47d8a749f4303a43
# 2  4876027b49457ecb
# 3  48761f9ac2a128c7
# 4  47d8ae95f533fc95

# %%
max(abs(df.latitude - df.lat)), max(abs(df.longitude - df.lon))
# Out:
# (4.346317439285485e-08, 6.312256317642095e-08)

# %%
# %%time
df["geohash"] = SpatialIndex.ppointcell(df.latitude, df.longitude, cell_type="geohash", res=10)
df.head()
# Out:
# CPU times: user 93.9 ms, sys: 104 ms, total: 197 ms
# Wall time: 1.56 s
#          date   time   latitude  longitude  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551  -0.097759                   1
# 1  07/01/2023  10:05  51.593701   0.022379                   1
# 2  14/01/2023  16:15  51.466689  -0.011289                   1
# 3  15/01/2023  19:51  51.671577  -0.037543                   1
# 4  16/01/2023  19:22  51.447944   0.117279                   2
#
#    number_of_casualties  speed_limit               h3        lat       lon  \
# 0                     1           30  8f194ac22370811  51.356551 -0.097759
# 1                     1           30  8f194e68042a851  51.593701  0.022379
# 2                     1           20  8f194ad058a4c04  51.466689 -0.011289
# 3                     1           30  8f195db6b2d6cca  51.671577 -0.037543
# 4                     1           30  8f194e6deb25ac9  51.447944  0.117279
#
#                  s2     geohash
# 0  487607526cb67e75  gcpujv0vd4
# 1  47d8a749f4303a43  u10j882716
# 2  4876027b49457ecb  gcpuz9pz0y
# 3  48761f9ac2a128c7  gcpvzns8v0
# 4  47d8ae95f533fc95  u10hdtv3uz

# %%
# %%time
df[["lat", "lon"]] = SpatialIndex.pcellpoint(df.geohash, cell_type="geohash")
df.head()
# Out:
# CPU times: user 39 ms, sys: 96.9 ms, total: 136 ms
# Wall time: 1.45 s
#          date   time   latitude  longitude  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551  -0.097759                   1
# 1  07/01/2023  10:05  51.593701   0.022379                   1
# 2  14/01/2023  16:15  51.466689  -0.011289                   1
# 3  15/01/2023  19:51  51.671577  -0.037543                   1
# 4  16/01/2023  19:22  51.447944   0.117279                   2
#
#    number_of_casualties  speed_limit               h3       lat     lon  \
# 0                     1           30  8f194ac22370811  51.35655 -0.0978
# 1                     1           30  8f194e68042a851  51.59370  0.0224
# 2                     1           20  8f194ad058a4c04  51.46669 -0.0113
# 3                     1           30  8f195db6b2d6cca  51.67158 -0.0375
# 4                     1           30  8f194e6deb25ac9  51.44794  0.1173
#
#                  s2     geohash
# 0  487607526cb67e75  gcpujv0vd4
# 1  47d8a749f4303a43  u10j882716
# 2  4876027b49457ecb  gcpuz9pz0y
# 3  48761f9ac2a128c7  gcpvzns8v0
# 4  47d8ae95f533fc95  u10hdtv3uz

# %%
max(abs(df.latitude - df.lat)), max(abs(df.longitude - df.lon))
# Out:
# (7.000000003642981e-06, 5.500000000002725e-05)
