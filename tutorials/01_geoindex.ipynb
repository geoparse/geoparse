# %% [markdown]
# # Visualization
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/geoparse/geoparse/main?labpath=tutorials%2F00_visualization.ipynb)
#
# <img align="right" src="data/geoparse_logo.png" alt="GeoParse Logo" width="200"/>
#
# This notebook demonstrates how to display:
#
# * Points, lines, and polygons.
# * Their heatmaps and clusters.
# * Their coverage areas using geospatial cells such as H3, S2, and Geohash.
# * Geospatial cells on a map based on their indexes.
# * OSM roads and buildings using their IDs.

# %%
import pandas as pd
import geopandas as gpd
from geoparse.karta import plp
from geoparse import gindex
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read from CSV file

# %%
df = pd.read_csv('data/great_britain_road_casualties-2023.csv')
df.head()
# Out:
#          date   time        lat       lon  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551 -0.097759                   1
# 1  07/01/2023  10:05  51.593701  0.022379                   1
# 2  14/01/2023  16:15  51.466689 -0.011289                   1
# 3  15/01/2023  19:51  51.671577 -0.037543                   1
# 4  16/01/2023  19:22  51.447944  0.117279                   2
#
#    number_of_casualties  speed_limit
# 0                     1           30
# 1                     1           30
# 2                     1           20
# 3                     1           30
# 4                     1           30

# %%
len(df)
# Out:
# 1522

# %%
plp(df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76c302989f1a2761d7e9de05342fe50c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76c302989f1a2761d7e9de05342fe50c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76c302989f1a2761d7e9de05342fe50c = L.map(
#                 &quot;map_76c302989f1a2761d7e9de05342fe50c&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_309a1f5bb06aa527595aac3abfd8ff8b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 21, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_309a1f5bb06aa527595aac3abfd8ff8b.addTo(map_76c302989f1a2761d7e9de05342fe50c);
#
#
#             var tile_layer_38d960ed08b614a695b2a288f2afa2f2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 21, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_38d960ed08b614a695b2a288f2afa2f2.addTo(map_76c302989f1a2761d7e9de05342fe50c);
#
#
#             var tile_layer_69af8761605633d1bcf416485b6695d2 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_69af8761605633d1bcf416485b6695d2.addTo(map_76c302989f1a2761d7e9de05342fe50c);
#
#
#             var tile_layer_e5a2d795aadab2ea6d2c35d9fcaba045 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e5a2d795aadab2ea6d2c35d9fcaba045.addTo(map_76c302989f1a2761d7e9de05342fe50c);
#
#
#             map_76c302989f1a2761d7e9de05342fe50c.fitBounds(
#                 [[50.108901, -6.606332], [60.252418, 1.725243]],
#                 {}
#             );
#
#
#             var feature_group_bb511af56a391727e60b4d40819685a9 = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_marker_311cfee57b95982c5b4e41b4786d3916 = L.circleMarker(
#                 [51.356551, -0.097759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(feature_group_bb511af56a391727e60b4d40819685a9);
#
#
#             var circle_marker_cc37cbeebe611b09cfad0e4c55e6ef76 = L.circleMarker(
#                 [51.593701, 0.022379],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(feature_group_bb511af56a391727e60b4d40819685a9);
#
#
#             var circle_marker_c328ae8e0313f73421a9aee878855c7d = L.circleMarker(
#                 [51.466689, -0.011289],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot

# %%
df = df.head(3)
df
# Out:
#          date   time        lat       lon  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551 -0.097759                   1
# 1  07/01/2023  10:05  51.593701  0.022379                   1
# 2  14/01/2023  16:15  51.466689 -0.011289                   1
#
#    number_of_casualties  speed_limit
# 0                     1           30
# 1                     1           30
# 2                     1           20

# %%
# %%time
df['h3'] = gindex.ppointcell(df.lat, df.lon, cell_type='h3', res=15)
df.head()
# Out:
# CPU times: user 9.54 ms, sys: 63.3 ms, total: 72.9 ms
# Wall time: 86 ms
#          date   time        lat       lon  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551 -0.097759                   1
# 1  07/01/2023  10:05  51.593701  0.022379                   1
# 2  14/01/2023  16:15  51.466689 -0.011289                   1
# 3  15/01/2023  19:51  51.671577 -0.037543                   1
# 4  16/01/2023  19:22  51.447944  0.117279                   2
#
#    number_of_casualties  speed_limit               h3
# 0                     1           30  8f194ac22370811
# 1                     1           30  8f194e68042a851
# 2                     1           20  8f194ad058a4c04
# 3                     1           30  8f195db6b2d6cca
# 4                     1           30  8f194e6deb25ac9

# %%
# %%time
df[['latitude', 'longitude']] = gindex.pcellpoint(df.h3, cell_type='h3')
df.head()
# Out:
# CPU times: user 26.1 ms, sys: 47.3 ms, total: 73.4 ms
# Wall time: 84.6 ms
#          date   time        lat       lon  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551 -0.097759                   1
# 1  07/01/2023  10:05  51.593701  0.022379                   1
# 2  14/01/2023  16:15  51.466689 -0.011289                   1
# 3  15/01/2023  19:51  51.671577 -0.037543                   1
# 4  16/01/2023  19:22  51.447944  0.117279                   2
#
#    number_of_casualties  speed_limit               h3   latitude  longitude
# 0                     1           30  8f194ac22370811  51.356552  -0.097765
# 1                     1           30  8f194e68042a851  51.593698   0.022381
# 2                     1           20  8f194ad058a4c04  51.466687  -0.011286
# 3                     1           30  8f195db6b2d6cca  51.671579  -0.037540
# 4                     1           30  8f194e6deb25ac9  51.447941   0.117280

# %%
max(abs(df.latitude - df.lat)), max(abs(df.longitude - df.lon))
# Out:
# (4.954881156038482e-06, 8.070243036950586e-06)

# %%
# %%time
df['s2'] = gindex.ppointcell(df.lat, df.lon, cell_type='s2', res=30)
df.head()
# Out:
# CPU times: user 52.8 ms, sys: 39.7 ms, total: 92.4 ms
# Wall time: 103 ms
#          date   time        lat       lon  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551 -0.097759                   1
# 1  07/01/2023  10:05  51.593701  0.022379                   1
# 2  14/01/2023  16:15  51.466689 -0.011289                   1
# 3  15/01/2023  19:51  51.671577 -0.037543                   1
# 4  16/01/2023  19:22  51.447944  0.117279                   2
#
#    number_of_casualties  speed_limit               h3   latitude  longitude  \
# 0                     1           30  8f194ac22370811  51.356552  -0.097765
# 1                     1           30  8f194e68042a851  51.593698   0.022381
# 2                     1           20  8f194ad058a4c04  51.466687  -0.011286
# 3                     1           30  8f195db6b2d6cca  51.671579  -0.037540
# 4                     1           30  8f194e6deb25ac9  51.447941   0.117280
#
#                  s2
# 0  487607526cb67e75
# 1  47d8a749f4303a43
# 2  4876027b49457ecb
# 3  48761f9ac2a128c7
# 4  47d8ae95f533fc95

# %%
# %%time
df[['latitude', 'longitude']] = gindex.pcellpoint(df.s2, cell_type='s2')
df.head()
# Out:
# CPU times: user 33.9 ms, sys: 57 ms, total: 90.9 ms
# Wall time: 111 ms
#          date   time        lat       lon  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551 -0.097759                   1
# 1  07/01/2023  10:05  51.593701  0.022379                   1
# 2  14/01/2023  16:15  51.466689 -0.011289                   1
# 3  15/01/2023  19:51  51.671577 -0.037543                   1
# 4  16/01/2023  19:22  51.447944  0.117279                   2
#
#    number_of_casualties  speed_limit               h3   latitude  longitude  \
# 0                     1           30  8f194ac22370811  51.356551  -0.097759
# 1                     1           30  8f194e68042a851  51.593701   0.022379
# 2                     1           20  8f194ad058a4c04  51.466689  -0.011289
# 3                     1           30  8f195db6b2d6cca  51.671577  -0.037543
# 4                     1           30  8f194e6deb25ac9  51.447944   0.117279
#
#                  s2
# 0  487607526cb67e75
# 1  47d8a749f4303a43
# 2  4876027b49457ecb
# 3  48761f9ac2a128c7
# 4  47d8ae95f533fc95

# %%
max(abs(df.latitude - df.lat)), max(abs(df.longitude - df.lon))
# Out:
# (4.346317439285485e-08, 6.312256317642095e-08)

# %%
# %%time
df['geohash'] = gindex.ppointcell(df.lat, df.lon, cell_type='geohash', res=10)
df.head()
# Out:
# CPU times: user 41.1 ms, sys: 44.7 ms, total: 85.8 ms
# Wall time: 103 ms
#          date   time        lat       lon  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551 -0.097759                   1
# 1  07/01/2023  10:05  51.593701  0.022379                   1
# 2  14/01/2023  16:15  51.466689 -0.011289                   1
# 3  15/01/2023  19:51  51.671577 -0.037543                   1
# 4  16/01/2023  19:22  51.447944  0.117279                   2
#
#    number_of_casualties  speed_limit               h3  latitude  longitude  \
# 0                     1           30  8f194ac22370811    51.357     -0.098
# 1                     1           30  8f194e68042a851    51.594      0.022
# 2                     1           20  8f194ad058a4c04    51.467     -0.011
# 3                     1           30  8f195db6b2d6cca    51.672     -0.038
# 4                     1           30  8f194e6deb25ac9    51.448      0.117
#
#                  s2     geohash
# 0  487607526cb67e75  gcpujv0vd4
# 1  47d8a749f4303a43  u10j882716
# 2  4876027b49457ecb  gcpuz9pz0y
# 3  48761f9ac2a128c7  gcpvzns8v0
# 4  47d8ae95f533fc95  u10hdtv3uz

# %%
# %%time
df[['latitude', 'longitude']] = gindex.pcellpoint(df.geohash, cell_type='geohash')
df.head()
# Out:
# CPU times: user 33.1 ms, sys: 52.7 ms, total: 85.8 ms
# Wall time: 94.5 ms
#          date   time        lat       lon  number_of_vehicles  \
# 0  03/01/2023  19:12  51.356551 -0.097759                   1
# 1  07/01/2023  10:05  51.593701  0.022379                   1
# 2  14/01/2023  16:15  51.466689 -0.011289                   1
# 3  15/01/2023  19:51  51.671577 -0.037543                   1
# 4  16/01/2023  19:22  51.447944  0.117279                   2
#
#    number_of_casualties  speed_limit               h3  latitude  longitude  \
# 0                     1           30  8f194ac22370811  51.35655    -0.0978
# 1                     1           30  8f194e68042a851  51.59370     0.0224
# 2                     1           20  8f194ad058a4c04  51.46669    -0.0113
# 3                     1           30  8f195db6b2d6cca  51.67158    -0.0375
# 4                     1           30  8f194e6deb25ac9  51.44794     0.1173
#
#                  s2     geohash
# 0  487607526cb67e75  gcpujv0vd4
# 1  47d8a749f4303a43  u10j882716
# 2  4876027b49457ecb  gcpuz9pz0y
# 3  48761f9ac2a128c7  gcpvzns8v0
# 4  47d8ae95f533fc95  u10hdtv3uz

# %%
max(abs(df.latitude - df.lat)), max(abs(df.longitude - df.lon))
# Out:
# (7.000000003642981e-06, 5.500000000002725e-05)
